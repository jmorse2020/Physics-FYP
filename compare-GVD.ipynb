# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
mandual_GVD_data = pd.read_csv("/Users/jackmorse/Desktop/manual-GVD-data.csv")
fft_GVD_data = pd.read_csv("/Users/jackmorse/Desktop/FFT-GVD-data.csv")
for column in fft_GVD_data.columns:
    print(column)
wavelengths_manual = mandual_GVD_data["wavelengths"]
GVD_manual = mandual_GVD_data["manual_GVD_ps_nmkm"]
wavelengths_fft = fft_GVD_data["wavelengths"]
GVD_fft = fft_GVD_data["GVD_nm_pskm"]
# Out:
# wavelengths
# GVD_nm_pskm

# %%
plt.plot(wavelengths_fft, GVD_fft)
plt.plot(wavelengths_manual, GVD_manual)
